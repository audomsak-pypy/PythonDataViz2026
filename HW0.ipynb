# %% [markdown]
# <a href="https://colab.research.google.com/github/audomsak-pypy/PythonDataViz2026/blob/main/HW0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *HW0* 673020271-0 #

# %%
print('673020271-0')
